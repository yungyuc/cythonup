# %%
from __future__ import print_function
from IPython.display import HTML, display
def go_board(s):
    stones = {x:i%2 for i,x in enumerate(map(eval, s))}
    def pos(i):
        return int(7+(220-6.5)*i/8)
    imgstr = "<img src='img/go%s.png' width='23px' height='23px' style='position: absolute; top: %spx; left: %spx;margin-top: 0' />"
    display(HTML("""<div style="width: 250px; height:250px;position: relative">
   <img src='img/Blank_Go_board_9x9.png' width="100%" height="100%" style="position: relative;left: 0;top: 0;margin-top: 0"/>
   """ + "\n".join(imgstr%('white' if c else 'black', pos(i), pos(j)) for (i,j),c in stones.items()) +"</div>"))

# %% [markdown]
# ### 先用 cython 編譯

# %%
! cd knapsack/;make
# Out:
# make: Nothing to be done for 'all'.

# %% [markdown]
# 先看看 python 跑的時間

# %%
# %%timeit -r 1 -n 1
# !python2 knapsack/knapsack_0_original.py knapsack/ks_10000_0
# Out:
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099870
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# ...

# %%
# %%timeit -r 1 -n 1
# !python3 knapsack/knapsack_0_original.py knapsack/ks_10000_0
# Out:
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099870
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# ...

# %% [markdown]
# 換成 pypy 看看

# %%
# %%timeit -r 1 -n 1
# !pypy knapsack/knapsack_0_original.py knapsack/ks_10000_0
# Out:
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099870
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# ...

# %% [markdown]
# 用 cython 跑看看

# %%
# %%timeit -r 1 -n 1
# !knapsack/knapsack_0_original knapsack/ks_10000_0
# Out:
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099870
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099871
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099873
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# 1099870 [3003, 568, 7055, 3023, 8034, 9756, 1824, 7577, 2168, 2946, 5620, 7234, 48, 6535, 9308, 1942, 9117, 6113] ub= 1099879
# ...

# %% [markdown]
# 試試看 knapsack_1_improved.py

# %%
# %%timeit -r 1 -n 1
# !python2 knapsack/knapsack_1_improved.py knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 31.7 s per loop

# %%
# %%timeit -r 1 -n 1
# !python3 knapsack/knapsack_1_improved.py knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 32.5 s per loop

# %%
# %%timeit -r 1 -n 1
# !pypy knapsack/knapsack_1_improved.py knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 4.01 s per loop

# %%
# %%timeit -r 1 -n 1
# !knapsack/knapsack_1_improved knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 30 s per loop

# %% [markdown]
# ### 加上型態?

# %%
# %%timeit -r 1 -n 1
# !python2 knapsack/knapsack_2_typed.py knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 33.1 s per loop

# %%
# %%timeit -r 1 -n 1
# !python3 knapsack/knapsack_2_typed.py knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 32.3 s per loop

# %%
# %%timeit -r 1 -n 1
# !pypy knapsack/knapsack_2_typed.py knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 5.31 s per loop

# %%
# %%timeit -r 1 -n 1
# !knapsack/knapsack_2_typed knapsack/ks_10000_0
# Out:
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 31.3 s per loop

# %% [markdown]
# ### Memoryview

# %%
# %%timeit -r 1 -n 1
# !python2 knapsack/knapsack_3_memoryview.py knapsack/ks_10000_0
# Out:
# intepreted
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 11.2 s per loop

# %%
# %%timeit -r 1 -n 1
# !python3 knapsack/knapsack_3_memoryview.py knapsack/ks_10000_0
# Out:
# intepreted
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 7.4 s per loop

# %%
# %%timeit -r 1 -n 1
# !pypy knapsack/knapsack_3_memoryview.py knapsack/ks_10000_0
# Out:
# can't import cython
# intepreted
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 4.36 s per loop

# %%
# %%timeit -r 1 -n 1
# !knapsack/knapsack_3_memoryview knapsack/ks_10000_0
# Out:
# compiled
# 1099870 6113
# 1099870 9117
# 1099870 1942
# 1099870 9308
# 1099870 6535
# 1099870 48
# 1099870 7234
# 1099870 5620
# 1099881 6535
# 1099881 4319
# 1099881 2946
# 1099881 2168
# 1099893 6113
# 1099893 7498
# 1099893 2827
# 1099893 2192
# 1099893 9431
# 1099893 2641
# 1099893 2946
# 1099893 7577
# 1099893 1824
# 1099893 9756
# 1099893 8034
# 1099893 3023
# 1099893 7055
# 1099893 568
# 1099893 3003
# 1 loops, best of 1: 474 ms per loop
